# %%
#Imports
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from PIL import Image
import cv2
import os
from tqdm import tqdm
from random import shuffle
import time
import math
from datetime import timedelta
from tensorflow.contrib.layers import dropout

# %%
from nnfunc import *
from myfunc import *

# %%
def label_img(img):
    word_label = img.split('.')[-3]
    # conversion to one-hot array [cat,dog]
    #                            [much cat, no dog]
    if word_label == 'cat': return [1,0]
    #                             [no cat, very doggo]
    elif word_label == 'dog': return [0,1]

# %%
# Create the data for the images and labels and save it into a .npy file
def create_data():
    data = [] 
    
    for img in tqdm(os.listdir(DATA_DIR)):
        label = label_img(img)
        path = os.path.join(DATA_DIR, img)
        img = Image.open(path)
        img = np.array(img)
        img = cv2.resize(img, (IMG_SIZE_PREPRO, IMG_SIZE_PREPRO))
        data.append([np.array(img), np.array(label)])

    shuffle(data)
    np.save(SAVED_DATA_FILE, data)

# %%
def split_image_label(data):
    images = np.array([i[0] for i in data]).reshape(-1,IMG_SIZE_PREPRO,IMG_SIZE_PREPRO, NB_CHANNELS)
    labels = np.array([i[1] for i in data])
    return images, labels

# %%
def augmented_train_image(image):
    # Randomly crop the input image.
    image = tf.random_crop(image, size=[IMG_SIZE, IMG_SIZE, NB_CHANNELS])
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_hue(image, max_delta=0.05)
    image = tf.image.random_contrast(image, lower=0.3, upper=1.0)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_saturation(image, lower=0.0, upper=2.0)
    
    # Limit the image pixels between [0, 1] in case of overflow.
    image = tf.minimum(image, 1.0)
    image = tf.maximum(image, 0.0)
    
    return image

# %%
def augmented_test_image(image):
    # Crop the input image around the centre so it is the same
    # size as images that are randomly cropped during training.
    image = tf.image.resize_image_with_crop_or_pad(image,
                                                   target_height=IMG_SIZE,
                                                   target_width=IMG_SIZE)
    return image

# %%
def pre_process_images(images, training):
    # Use TensorFlow to loop over all the input images and call
    # the function above which takes a single image as input.
    images = tf.cond(training, 
                     lambda: tf.map_fn(lambda image: augmented_train_image(image), images),
                     lambda: tf.map_fn(lambda image: augmented_test_image(image), images))

    return images

# %%
def optimize(epoch, train_images, train_labels, batch_size=64):
    # Total number of batches in our training set.
    nb_batches = int(np.ceil(len(train_images)/batch_size))
    start_time = time.time()
    nb_past_steps = session.run(global_step)

    for i in range(nb_past_steps, nb_past_steps + epoch):
        # Get a batch of training examples to feed and run the optimizer
        current_batch_index = i % nb_batches
        x_batch, y_true_batch = fetch_batch(train_images, train_labels, 
                                            batch_size, current_batch_index)
        feed_dict_train = {x: x_batch, y_true: y_true_batch, training: True}
        session.run(optimizer, feed_dict=feed_dict_train)

        # Print status every 100 iterations.
        if i % 100 == 99:
            current_acc = session.run(accuracy, feed_dict=feed_dict_train)
            current_loss = session.run(loss, feed_dict=feed_dict_train)
            msg = "Optimization Iteration: {0}, Training Accuracy: {1:.1%}, Training Loss: {2}"
            print(msg.format(i + 1, current_acc, current_loss))
 
    #Time used 
    end_time = time.time()
    time_dif = end_time - start_time
    print("Time usage: " + str(timedelta(seconds=int(round(time_dif)))))

# %%
# Print the testing accuracy
def testing_accuracy(test_images, test_labels, batch_size=64, confusion_matrix=False, example_errors=False):
    # Number of images in the test-set
    nb_test = len(test_images)
    
    #Array to store the predicted classes for each test image
    cls_pred = np.zeros(shape=nb_test, dtype=np.int)
    
    # Total number of batches in our testing set.
    nb_batches = int(np.ceil(nb_test/batch_size))
    
    for i in tqdm(range(0, nb_batches)):
        x_batch, y_true_batch = fetch_batch(test_images, test_labels, batch_size, i)
        feed_dict = {x: x_batch, y_true: y_true_batch, training: False}
        
        # Calculate the predicted class for each test image
        cls_pred[(i*batch_size):min((i*batch_size+batch_size), nb_test)] = session.run(y_pred_cls, feed_dict=feed_dict)
        
    cls_true = np.array([np.argmax(i) for i in test_labels])
    correct = (cls_true == cls_pred)
    correct_sum = correct.sum()
    test_acc = float(correct_sum) / nb_test    
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(test_acc, correct_sum, nb_test))
    
    if confusion_matrix:
        plot_confusion_matrix(cls_pred, cls_true)
    if example_errors:
        plot_example_errors(test_images, cls_true, cls_pred)

# %%
# Test the model on one image
def test_one_image(image, label, altered=False):
    feed_dict = {x: [image], y_true: [label], training: altered}
    pred = session.run(y_pred, feed_dict=feed_dict)
    augmented_image = session.run(aug_images, feed_dict=feed_dict).reshape(IMG_SIZE,IMG_SIZE, NB_CHANNELS)
    plot_image(augmented_image, label, pred)

# %%
# Constant values 128-112, 64-60
DATA_DIR = 'train/train'
SAVED_DATA_FILE = 'data128.npy'
BATCH_SIZE = 64
IMG_SIZE_PREPRO = 128
IMG_SIZE = 112
NB_CHANNELS = 3
GREYSCALE = False
LR = 1e-4

# %%
# Take the images from the folder, extract the label, same all the samples into a .npy file
#create_data()

# %%
# Load the data from the .npy file
data = np.load(SAVED_DATA_FILE)

# %%
# Splitting into train and test set
train = data[:20000]
test = data[20000:]

# %%
# Separating images and labels
train_images, train_labels = split_image_label(train)
test_images, test_labels = split_image_label(test)

# %%
# Values of each pixel in 0-1
train_images = train_images/255
test_images = test_images/255

# %%
num = 6
plot_image(train_images[num], train_labels[num])
# Out:
# True: [1 0]

# %%
x = tf.placeholder(tf.float32, shape=[None, IMG_SIZE_PREPRO, IMG_SIZE_PREPRO, NB_CHANNELS], name='x')
y_true = tf.placeholder(tf.float32, shape=[None, 2], name='y_true')
y_true_cls = tf.argmax(y_true, axis=1)
training = tf.placeholder(tf.bool)
global_step = tf.Variable(initial_value=0, name='global_step', trainable=False)

# %%
#Data augmentation
aug_images = pre_process_images(images=x, training=training)

#CNN
layer_conv1 = conv_2d(aug_images, NB_CHANNELS, 5, 32, use_pooling=True)
layer_conv2 = conv_2d(layer_conv1, 32, 5, 32, use_pooling=True)
layer_conv3 = conv_2d(layer_conv2, 32, 5, 32, use_pooling=True)
layer_conv4 = conv_2d(layer_conv3, 32, 5, 32, use_pooling=True)
layer_conv5 = conv_2d(layer_conv4, 32, 5, 32, use_pooling=True)
layer_conv6 = conv_2d(layer_conv5, 32, 5, 32, use_pooling=True)
layer_conv7 = conv_2d(layer_conv6, 32, 5, 32, use_pooling=True)
layer_conv8 = conv_2d(layer_conv7, 32, 5, 32, use_pooling=True)


#FCNN
layer_flat, num_features = flatten_layer(layer_conv8)
layer_fc1 = fc_layer(layer_flat, num_features, 256, use_relu=True)
layer_fc2 = fc_layer(dropout(layer_fc1, 0.2), 256, 256, use_relu=True)
layer_fc3 = fc_layer(dropout(layer_fc2, 0.2), 256, 256, use_relu=True)
layer_fc4 = fc_layer(dropout(layer_fc3, 0.2), 256, 2, use_relu=False)

#prediction
y_pred = tf.nn.softmax(layer_fc4)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=layer_fc4, labels=y_true)
loss = tf.reduce_mean(cross_entropy)

# %%
#optimization
optimizer = tf.train.AdamOptimizer(learning_rate=LR).minimize(loss, global_step=global_step)

# %%
# Performance measures for testing
y_pred_cls = tf.argmax(y_pred, axis=1)
correct_prediction = tf.equal(y_pred_cls, y_true_cls)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
#session
saver = tf.train.Saver()
session = tf.Session()
session.run(tf.global_variables_initializer())

# %%
num = 8
image = test_images[num]
label = test_labels[num]
test_one_image(image, label, False)
# Out:
# True: [1 0], Pred: [[0.99743736 0.00256265]]

# %%
for i in range(10):
    optimize(1000, train_images, train_labels, BATCH_SIZE)
    testing_accuracy(test_images, test_labels, BATCH_SIZE)
# Out:
# Optimization Iteration:  10100, Training Accuracy:  87.5%, Training Loss:    0.3
# Optimization Iteration:  10200, Training Accuracy:  92.2%, Training Loss:    0.3
# Optimization Iteration:  10300, Training Accuracy:  96.9%, Training Loss:    0.3
# Optimization Iteration:  10400, Training Accuracy:  96.9%, Training Loss:    0.2
# Optimization Iteration:  10500, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  10600, Training Accuracy:  90.6%, Training Loss:    0.3
# Optimization Iteration:  10700, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  10800, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  10900, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  11000, Training Accuracy:  87.5%, Training Loss:    0.2
# Time usage: 0:59:05
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:28<00:00,  1.12s/it]
# Accuracy on Test-Set: 90.1% (4542 / 5041)
# Optimization Iteration:  11100, Training Accuracy:  95.3%, Training Loss:    0.2
# Optimization Iteration:  11200, Training Accuracy:  90.6%, Training Loss:    0.1
# Optimization Iteration:  11300, Training Accuracy:  87.5%, Training Loss:    0.1
# Optimization Iteration:  11400, Training Accuracy:  95.3%, Training Loss:    0.3
# Optimization Iteration:  11500, Training Accuracy:  89.1%, Training Loss:    0.2
# Optimization Iteration:  11600, Training Accuracy:  98.4%, Training Loss:    0.1
# Optimization Iteration:  11700, Training Accuracy:  89.1%, Training Loss:    0.2
# Optimization Iteration:  11800, Training Accuracy:  96.9%, Training Loss:    0.1
# Optimization Iteration:  11900, Training Accuracy:  90.6%, Training Loss:    0.2
# Optimization Iteration:  12000, Training Accuracy:  90.6%, Training Loss:    0.1
# Time usage: 0:58:45
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:37<00:00,  1.23s/it]
# Accuracy on Test-Set: 90.5% (4562 / 5041)
# Optimization Iteration:  12100, Training Accuracy:  95.3%, Training Loss:    0.1
# Optimization Iteration:  12200, Training Accuracy:  92.2%, Training Loss:    0.1
# Optimization Iteration:  12300, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  12400, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  12500, Training Accuracy:  98.4%, Training Loss:    0.1
# Optimization Iteration:  12600, Training Accuracy:  93.8%, Training Loss:    0.1
# Optimization Iteration:  12700, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  12800, Training Accuracy:  95.3%, Training Loss:   0.09
# Optimization Iteration:  12900, Training Accuracy:  96.9%, Training Loss:    0.2
# Optimization Iteration:  13000, Training Accuracy:  85.9%, Training Loss:    0.2
# Time usage: 0:58:56
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:33<00:00,  1.18s/it]
# Accuracy on Test-Set: 90.6% (4569 / 5041)
# Optimization Iteration:  13100, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  13200, Training Accuracy:  96.9%, Training Loss:   0.07
# Optimization Iteration:  13300, Training Accuracy:  90.6%, Training Loss:    0.1
# Optimization Iteration:  13400, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  13500, Training Accuracy:  95.3%, Training Loss:    0.2
# Optimization Iteration:  13600, Training Accuracy:  90.6%, Training Loss:    0.3
# Optimization Iteration:  13700, Training Accuracy:  98.4%, Training Loss:   0.07
# Optimization Iteration:  13800, Training Accuracy:  95.3%, Training Loss:    0.1
# Optimization Iteration:  13900, Training Accuracy:  96.9%, Training Loss:    0.2
# Optimization Iteration:  14000, Training Accuracy:  96.9%, Training Loss:    0.1
# Time usage: 0:58:59
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:31<00:00,  1.16s/it]
# Accuracy on Test-Set: 91.1% (4590 / 5041)
# Optimization Iteration:  14100, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  14200, Training Accuracy:  96.9%, Training Loss:   0.08
# Optimization Iteration:  14300, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  14400, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  14500, Training Accuracy:  96.9%, Training Loss:   0.09
# Optimization Iteration:  14600, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  14700, Training Accuracy:  95.3%, Training Loss:    0.1
# Optimization Iteration:  14800, Training Accuracy:  90.6%, Training Loss:    0.2
# Optimization Iteration:  14900, Training Accuracy:  98.4%, Training Loss:    0.2
# Optimization Iteration:  15000, Training Accuracy:  95.3%, Training Loss:    0.1
# Time usage: 0:58:51
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:31<00:00,  1.16s/it]
# Accuracy on Test-Set: 90.5% (4561 / 5041)
# Optimization Iteration:  15100, Training Accuracy:  93.8%, Training Loss:   0.08
# Optimization Iteration:  15200, Training Accuracy:  93.8%, Training Loss:    0.1
# Optimization Iteration:  15300, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  15400, Training Accuracy:  95.3%, Training Loss:   0.09
# Optimization Iteration:  15500, Training Accuracy:  93.8%, Training Loss:    0.1
# Optimization Iteration:  15600, Training Accuracy:  90.6%, Training Loss:    0.4
# Optimization Iteration:  15700, Training Accuracy:  95.3%, Training Loss:    0.2
# Optimization Iteration:  15800, Training Accuracy:  96.9%, Training Loss:    0.1
# Optimization Iteration:  15900, Training Accuracy:  96.9%, Training Loss:    0.1
# Optimization Iteration:  16000, Training Accuracy:  92.2%, Training Loss:    0.1
# Time usage: 0:58:52
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:41<00:00,  1.28s/it]
# Accuracy on Test-Set: 91.0% (4587 / 5041)
# Optimization Iteration:  16100, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  16200, Training Accuracy:  95.3%, Training Loss:   0.06
# Optimization Iteration:  16300, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  16400, Training Accuracy:  96.9%, Training Loss:    0.1
# Optimization Iteration:  16500, Training Accuracy:  92.2%, Training Loss:    0.2
# Optimization Iteration:  16600, Training Accuracy:  96.9%, Training Loss:    0.1
# Optimization Iteration:  16700, Training Accuracy:  95.3%, Training Loss:    0.2
# Optimization Iteration:  16800, Training Accuracy: 100.0%, Training Loss:   0.09
# Optimization Iteration:  16900, Training Accuracy:  93.8%, Training Loss:    0.1
# Optimization Iteration:  17000, Training Accuracy:  93.8%, Training Loss:    0.1
# Time usage: 0:58:57
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:28<00:00,  1.12s/it]
# Accuracy on Test-Set: 89.7% (4524 / 5041)
# Optimization Iteration:  17100, Training Accuracy:  93.8%, Training Loss:    0.2
# Optimization Iteration:  17200, Training Accuracy:  92.2%, Training Loss:    0.1
# Optimization Iteration:  17300, Training Accuracy:  95.3%, Training Loss:   0.09
# Optimization Iteration:  17400, Training Accuracy:  98.4%, Training Loss:   0.07
# Optimization Iteration:  17500, Training Accuracy:  89.1%, Training Loss:    0.2
# Optimization Iteration:  17600, Training Accuracy:  98.4%, Training Loss:    0.1
# Optimization Iteration:  17700, Training Accuracy:  95.3%, Training Loss:    0.2
# Optimization Iteration:  17800, Training Accuracy:  96.9%, Training Loss:   0.07
# Optimization Iteration:  17900, Training Accuracy: 100.0%, Training Loss:   0.06
# Optimization Iteration:  18000, Training Accuracy:  93.8%, Training Loss:    0.1
# Time usage: 0:58:58
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:31<00:00,  1.16s/it]
# Accuracy on Test-Set: 91.3% (4601 / 5041)
# Optimization Iteration:  18100, Training Accuracy:  95.3%, Training Loss:   0.05
# Optimization Iteration:  18200, Training Accuracy:  96.9%, Training Loss:    0.1
# Optimization Iteration:  18300, Training Accuracy:  95.3%, Training Loss:    0.1
# Optimization Iteration:  18400, Training Accuracy:  95.3%, Training Loss:    0.1
# Optimization Iteration:  18500, Training Accuracy:  95.3%, Training Loss:    0.1
# Optimization Iteration:  18600, Training Accuracy:  96.9%, Training Loss:   0.06
# Optimization Iteration:  18700, Training Accuracy:  98.4%, Training Loss:   0.07
# Optimization Iteration:  18800, Training Accuracy: 100.0%, Training Loss:   0.02
# Optimization Iteration:  18900, Training Accuracy: 100.0%, Training Loss:   0.07
# Optimization Iteration:  19000, Training Accuracy:  96.9%, Training Loss:   0.09
# Time usage: 0:58:45
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:30<00:00,  1.15s/it]
# Accuracy on Test-Set: 90.6% (4569 / 5041)
# Optimization Iteration:  19100, Training Accuracy:  96.9%, Training Loss:   0.08
# Optimization Iteration:  19200, Training Accuracy:  95.3%, Training Loss:    0.2
# Optimization Iteration:  19300, Training Accuracy:  92.2%, Training Loss:   0.08
# Optimization Iteration:  19400, Training Accuracy:  93.8%, Training Loss:   0.06
# Optimization Iteration:  19500, Training Accuracy:  93.8%, Training Loss:   0.04
# Optimization Iteration:  19600, Training Accuracy:  92.2%, Training Loss:   0.04
# Optimization Iteration:  19700, Training Accuracy:  98.4%, Training Loss:   0.05
# Optimization Iteration:  19800, Training Accuracy:  96.9%, Training Loss:   0.07
# Optimization Iteration:  19900, Training Accuracy:  95.3%, Training Loss:   0.03
# Optimization Iteration:  20000, Training Accuracy:  95.3%, Training Loss:    0.1
# Time usage: 0:58:50
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:32<00:00,  1.18s/it]
# Accuracy on Test-Set: 90.6% (4565 / 5041)

# %%
# Testing
testing_accuracy(test_images, test_labels, BATCH_SIZE, confusion_matrix=True, example_errors=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [01:11<00:00,  1.11it/s]
# Accuracy on Test-Set: 90.7% (4570 / 5041)
# [[2362  168]
#  [ 303 2208]]

# %%
# Restore model
saver.restore(session, 'saved_model/first_try')
# Out:
# INFO:tensorflow:Restoring parameters from saved_model/classification_64p_32c_1024f_3k_color_allpix_4conv-50000

# %%
# Save model
saver.save(session, 'saved_model/classification_75p_32c_1024f_3k_color_allpix_2conv', global_step=global_step)
# Out:
# 'saved_model/classification_75p_32c_1024f_3k_color_allpix_2conv-0'
